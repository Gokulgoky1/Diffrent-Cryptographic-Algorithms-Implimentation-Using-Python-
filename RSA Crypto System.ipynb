# %% [markdown]
# # Functions

# %%
import math

# %%
def expo(x,n,pro):
  if(n>=0):
    if (n%2==1):
      pro=pro*x
      n=n-1
    if(n>0): 
      x=x*x
      return expo(x,n/2,pro)
    return pro

# %%
def modInverse(a):
  for i in range (fi):
    if (i*a%fi==1):
      return i
  return -1

# %%
def pri_not(k):
  o=0
  for i in range(1,k+1):
    if(k%i==0):
      o+=1
      if(o>2):
        return 1
        break

# %% [markdown]
# # RSA Encryption Decryption

# %%
def encry(M):
  c=expo(M,e,1)%n
  return c
def decry(C):
  pt=expo(C,d,1)%n
  return pt

# %% [markdown]
# # RSA

# %%
p=int(input("enter the value  of P:"))
while(True):
  if pri_not(p)!=1:
    break
  else:
    p=int(input("enter the value  of P:"))
q=int(input("enter the value  of Q:"))
while(True):
  if pri_not(q)!=1:
    break
  else:
    q=int(input("enter the value  of Q:"))
n=p*q
fi=(p-1)*(q-1)
e=int(input("Enter the value of e:"))
while(True):
  if(math.gcd(e,fi)==1 and e<fi):
    break
  else:
    e=int(input("Enter the value of e:"))
d=modInverse(e)
print("d=",d)
print("Public Key","{",e,",",n,'}')
m=int(input("Enter the plane text:"))
c=encry(m)
print("Encrypted text:",c)
PT=decry(c)
print("Decrypted text:",PT)
# Out:
# enter the value  of P:11
# enter the value  of Q:17
# Enter the value of e:3
# d= 107
# Public Key { 3 , 187 }
# Enter the plane text:88
# Encrypted text: 44
# Decrypted text: 88
